# %% [markdown]
# ## 월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회

# %% [markdown]
# 1. 배경
#
#
# 안녕하세요 여러분! 🙌 신용카드 사용자 연체 예측 AI 경진대회에 오신 것을 환영합니다.
#
#
#
# 신용카드사는 신용카드 신청자가 제출한 개인정보와 데이터를 활용해 신용 점수를 산정합니다.
#
# 신용카드사는 이 신용 점수를 활용해 신청자의 향후 채무 불이행과 신용카드 대급 연체 가능성을 예측합니다.
#
# 현재 많은 금융업계는 인공지능(AI)를 활용한 금융 서비스를 구현하고자 합니다.
#
#
#
# 신용카드 사용자들의 개인 신상정보 데이터로 사용자의 신용카드 대금 연체 정도를 예측할 수 있는
#
# 인공지능 알고리즘을 개발해 금융업계에 제안할 수 있는 인사이트를 발굴해주세요!
#
#
# 2. 목적
#
#
# 신용카드 사용자 데이터를 보고 사용자의 대금 연체 정도를 예측하는 알고리즘 개발

# %% [markdown]
# 3. 변수 설명

# %% [markdown]
# * index
# * gender: 성별
# * car: 차량 소유 여부
# * reality: 부동산 소유 여부
# * child_num: 자녀 수
# * income_total: 연간 소득
# * income_type: 소득 분류
# 		['Commercial associate', 'Working', 'State servant', 'Pensioner', 'Student']
#
# * edu_type: 교육 수준
# 		['Higher education' ,'Secondary / secondary special', 'Incomplete higher', 'Lower secondary', 'Academic degree']
#
# * family_type: 결혼 여부
# 		['Married', 'Civil marriage', 'Separated', 'Single / not married', 'Widow']
#
# * house_type: 생활 방식
# 		['Municipal apartment', 'House / apartment', 'With parents','Co-op apartment', 'Rented apartment', 'Office apartment']
#
# * DAYS_BIRTH: 출생일
# 		데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전에 태어났음을 의미
#
# * DAYS_EMPLOYED: 업무 시작일
# 		데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전부터 일을 시작함을 의미
#
# 		양수 값은 고용되지 않은 상태를 의미함
#
# * FLAG_MOBIL: 핸드폰 소유 여부
# * work_phone: 업무용 전화 소유 여부
# * phone: 전화 소유 여부
# * email: 이메일 소유 여부
# * occyp_type: 직업 유형
# * family_size: 가족 규모
# * begin_month: 신용카드 발급 월
# 		데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 한 달 전에 신용카드를 발급함을 의미
#
# * credit: 사용자의 신용카드 대금 연체를 기준으로 한 신용도
# 		낮을 수록 높은 신용의 신용카드 사용자를 의미함

# %%
# pandas, numpy, matplotlib.pyplot, seaborn, os 등 필요 라이브러리 호출

import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 모든 행을 출력
pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/test.csv')

# %%
train.head()
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
# 2      2      M   Y       Y          0      450000.0               Working
# 3      3      F   N       Y          0      202500.0  Commercial associate
# 4      4      F   Y       Y          0      157500.0         State servant
#
#                         edu_type     family_type           house_type  \
# 0               Higher education         Married  Municipal apartment
# 1  Secondary / secondary special  Civil marriage    House / apartment
# 2               Higher education         Married    House / apartment
# 3  Secondary / secondary special         Married    House / apartment
# 4               Higher education         Married    House / apartment
#
#    DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %% [markdown]
# * Categorical Data
#
#   * gender
#   * car
#   * reality
#   * income_type
#   * edu_type
#   * family_type
#   * house_type
#   * occyp_type
#
# * Continuous Data
#   * index
#   * income_type
#   * DAYS_BIRTH
#   * DAYS_EMPLOYED
#   * FLAG_MOBIL
#   * work_phone
#   * phone
#   * email
#   * family_size
#   * begin_month
#   * credit

# %%
test.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       3152
# family_size         0
# begin_month         0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %% [markdown]
# * occyp_type : 결측치

# %%
train['occyp_type'] = train['occyp_type'].fillna('NaN')
test['occyp_type'] = test['occyp_type'].fillna('NaN')

# %%
train.isnull().sum()
# Out:
# index            0
# gender           0
# car              0
# reality          0
# child_num        0
# income_total     0
# income_type      0
# edu_type         0
# family_type      0
# house_type       0
# DAYS_BIRTH       0
# DAYS_EMPLOYED    0
# FLAG_MOBIL       0
# work_phone       0
# phone            0
# email            0
# occyp_type       0
# family_size      0
# begin_month      0
# credit           0
# dtype: int64

# %%
train.describe()
# Out:
#               index     child_num  income_total    DAYS_BIRTH  DAYS_EMPLOYED  \
# count  26457.000000  26457.000000  2.645700e+04  26457.000000   26457.000000
# mean   13228.000000      0.428658  1.873065e+05 -15958.053899   59068.750728
# std     7637.622372      0.747326  1.018784e+05   4201.589022  137475.427503
# min        0.000000      0.000000  2.700000e+04 -25152.000000  -15713.000000
# 25%     6614.000000      0.000000  1.215000e+05 -19431.000000   -3153.000000
# 50%    13228.000000      0.000000  1.575000e+05 -15547.000000   -1539.000000
# 75%    19842.000000      1.000000  2.250000e+05 -12446.000000    -407.000000
# max    26456.000000     19.000000  1.575000e+06  -7705.000000  365243.000000
#
#        FLAG_MOBIL    work_phone         phone         email   family_size  \
# count     26457.0  26457.000000  26457.000000  26457.000000  26457.000000
# mean          1.0      0.224742      0.294251      0.091280      2.196848
# ...

# %%
train['index'].value_counts()
# Out:
# 0        1
# 17635    1
# 17645    1
# 17644    1
# 17643    1
#         ..
# 8816     1
# 8815     1
# 8814     1
# 8813     1
# 26456    1
# Name: index, Length: 26457, dtype: int64

# %% [markdown]
# * FLAG_MOBIL : 모든 값이 1로 수렴, 피처 삭제
# * index : 모든데이터 값이 0 ~ 26356의 하나씩의 값을 다 가짐, 피처 삭제
# * child_num : 자녀의 수의 평균 0.42 / max : 19의 값 '이상치', 이상치 확인
# * DAYS_EMPLOYED : 양수 값은 고용되지 않은 상태를 의미함 고용되지 않은 값 : 0으로 변경
# * family_size : 가구 구성원 수의 평균 2.1 / max : 20의 값 '이상치' 이상치 확인
# * credit : 0, 1, 2의 값을 가지지만 평균 1.5 따라서 2의 분포가 더 많을 것으로 판단

# %%
train.describe(include = 'O')
# Out:
#        gender    car reality income_type                       edu_type  \
# count   26457  26457   26457       26457                          26457
# unique      2      2       2           5                              5
# top         F      N       Y     Working  Secondary / secondary special
# freq    17697  16410   17830       13645                          17995
#
#        family_type         house_type occyp_type
# count        26457              26457      26457
# unique           5                  6         19
# top        Married  House / apartment        NaN
# freq         18196              23653       8171

# %% [markdown]
# * Gender(성별) : unique의 개수 2개, Female의 비율이 많다.
# * Car(차량 소지) : unique의 개수 2개, N의 비율이 많다.
# * reality(부동산 소지) : unique의 개수 2개, Y의 비율이 많다.

# %% [markdown]
# 1. 연령 (Age): DAYS_BIRTH를 이용하여 계산
#
# 2. 근속 기간 (Employment duration): DAYS_EMPLOYED를 이용하여 계산
#
# 3. 신용카드 사용 기간 (Credit card usage duration): 현재 월(begin_month)에서 카드 발급 월을 뺀 값

# %% [markdown]
# ### 데이터 클랜징

# %% [markdown]
# * **컬럼 제거 : 'FLAG_MOBIL', 'index'**

# %%
train.drop(['FLAG_MOBIL','index'], axis = 1, inplace = True)
test.drop(['FLAG_MOBIL','index'], axis = 1, inplace = True)

# %% [markdown]
# * **child_num : 자녀의 수의 평균 0.42 / max : 19의 값 '이상치', 이상치 확인**

# %%
train.sort_values('child_num', ascending = False).head(20)
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 10731      F   N       Y         19      112500.0               Working
# 8462       M   Y       Y         14      225000.0               Working
# 25390      M   Y       Y         14      225000.0               Working
# 9021       M   Y       Y         14      225000.0               Working
# 25313      F   N       N          7      157500.0               Working
# 25638      F   N       N          7      157500.0               Working
# 10321      M   Y       Y          5      202500.0               Working
# 20117      F   N       Y          5      157500.0               Working
# 17978      M   Y       Y          5      202500.0               Working
# 17560      F   N       Y          5      157500.0               Working
# 12876      F   N       Y          5      157500.0               Working
# 9615       M   Y       Y          5      202500.0               Working
# ...

# %%
# 숫자형 변수 단변량 분석 함수

def eda_1_n(var, data) :

    #기초통계량 (데이터프레임 형태)
    display(train[[var]].describe().T)  

    #시각화
    plt.figure(figsize = (12, 8))  # 그래프 크기 조절
    plt.subplot(2, 1, 1)  # 2행 1열로 1번째 그래프
    sns.histplot(x = var, data = data, kde = True)
    plt.grid()

    plt.subplot(2, 1, 2) # 2행 1열로 2번째 그래프
    sns.boxplot(x = var , data = data)
    plt.grid()  # 격자 추가

    plt.show()  # 그래프 print

# %%
eda_1_n('child_num', train)
# Out:
#              count      mean       std  min  25%  50%  75%   max
# child_num  26457.0  0.428658  0.747326  0.0  0.0  0.0  1.0  19.0

# %%
train = train[train['child_num'] < 4]

# %%
eda_1_n('child_num', train)
# Out:
#              count      mean       std  min  25%  50%  75%  max
# child_num  26394.0  0.417822  0.701289  0.0  0.0  0.0  1.0  3.0

# %% [markdown]
# * child_num의 값이 가장 큰 데이터 : 19명의 아이를 가지고 있지만 결혼을 하지 않음 > 입양에 관한 내용인진 모르겠지만 이상치로 처리
#
# * child_num의 값 = 14 : 3개의 값을 가지고 있는데 카드 발급일(begin_month)에 대한 값을 제외하고 동일한 것을 확인 할 수 있음
#
# * child_num의 값 = 7 : 2개의 값을 가지고 있는데 카드 발급일(begin_month)에 대한 값을 제외하고 동일한 것을 확인 할 수 있음
#
# > child_num : 자녀 수의 이상치는 2.5 ~ 부터 나타나는 것으로 파악 > 우선적으로 4명 이상의 아이에 대해서 제거하고 분석 진행
#
# > 카드 발급일(begin_month)에 대한 값을 제외하고 동일한 것을 확인 할 수 있음, 이 값에 대해서 처리를 어떻게 해야하는지 분석 진행

# %% [markdown]
# * **DAYS_EMPLOYED : 고용일에 대한 클랜징 진행**
#   * 0보다 큰 값은 0으로 변경

# %%
train[train['DAYS_EMPLOYED'] >= 0]
# Out:
#       gender car reality  child_num  income_total income_type  \
# 14         F   N       Y          0      157500.0   Pensioner
# 18         F   N       Y          0      216000.0   Pensioner
# 21         F   N       N          0      157500.0   Pensioner
# 24         F   N       N          0      202500.0   Pensioner
# 46         F   N       N          0      135000.0   Pensioner
# ...      ...  ..     ...        ...           ...         ...
# 26431      F   N       Y          0      225000.0   Pensioner
# 26432      F   Y       Y          0       72000.0   Pensioner
# 26439      F   N       Y          0       67500.0   Pensioner
# 26441      F   N       Y          0       90000.0   Pensioner
# 26443      F   N       Y          0       90000.0   Pensioner
#
#                             edu_type           family_type         house_type  \
# 14     Secondary / secondary special  Single / not married  House / apartment
# ...

# %%
train[train['DAYS_EMPLOYED'] >= 0]['DAYS_EMPLOYED'].nunique()
# Out:
# 1

# %%
train['DAYS_EMPLOYED'] = train['DAYS_EMPLOYED'].replace({365243 : 0})
test['DAYS_EMPLOYED'] = test['DAYS_EMPLOYED'].replace({365243 : 0})

# %%
train[train['DAYS_EMPLOYED'] > 0]
# Out:
# Empty DataFrame
# Columns: [gender, car, reality, child_num, income_total, income_type, edu_type, family_type, house_type, DAYS_BIRTH, DAYS_EMPLOYED, work_phone, phone, email, occyp_type, family_size, begin_month, credit]
# Index: []

# %% [markdown]
# * 0보다 큰 값들은 모두 1개의 값이며, 그 값은 '365243'안 것을 확인 할 수 있음 > 0으로 변경

# %% [markdown]
# * **parents_num : 가구 구성원 수의 평균 2.1 / max : 20의 값 '이상치' 이상치 확인**

# %%
train['parents_num'] = train['family_size'] - train['child_num']
test['parents_num'] = test['family_size'] - test['child_num']

# %%
train['parents_num'].unique()
# Out:
# array([ 2.,  1.,  0., -1.])

# %%
train[train['parents_num'].isin([0,-1])]
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 5825       M   Y       Y          1      450000.0  Commercial associate
# 14900      M   Y       N          2      225000.0               Working
# 16110      F   N       Y          1      108000.0               Working
# 16791      F   N       Y          1      126000.0               Working
# 18879      M   N       Y          1      126000.0  Commercial associate
# 21096      M   N       N          1      157500.0               Working
#
#                             edu_type           family_type         house_type  \
# 5825   Secondary / secondary special  Single / not married  House / apartment
# 14900  Secondary / secondary special               Married  House / apartment
# 16110  Secondary / secondary special  Single / not married  House / apartment
# 16791  Secondary / secondary special               Married  House / apartment
# ...

# %% [markdown]
# * family_child의 열을 봤을 때, 가족 구성원 : 자녀의 수 + 부모의 수
#
# * 따라서 가족 구성원 수에서 아이의 수를 뻈을 때, 0이나 -1이 나올 수 없다.

# %%
train = train[train['parents_num'] > 0]

# %%
train.sort_values('parents_num', ascending = False).head(20)
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 0          F   N       N          0      202500.0  Commercial associate
# 16444      F   Y       N          0      144000.0  Commercial associate
# 16471      F   Y       Y          2      450000.0               Working
# 16470      M   N       N          1      225000.0               Working
# 16467      M   Y       N          0      207000.0               Working
# 16465      M   Y       N          0      202500.0             Pensioner
# 16464      F   N       Y          2      112500.0  Commercial associate
# 16463      F   N       N          0      135000.0         State servant
# 16462      F   N       Y          0      225000.0  Commercial associate
# 16461      F   N       Y          0      112500.0             Pensioner
# 16460      M   N       N          1      315000.0  Commercial associate
# 16459      F   N       Y          0      117000.0             Pensioner
# ...

# %%
eda_1_n('parents_num', train)
# Out:
#                count      mean       std  min  25%  50%  75%  max
# parents_num  26388.0  1.768417  0.421852  1.0  2.0  2.0  2.0  2.0

# %% [markdown]
# * 자녀의 수와 가족 구성원의 수는 관련이 있기 때문에, 자녀의 수에 대한 전처리로 인해 이상치가 줄어든 것을 확인 할 수 있다.

# %% [markdown]
# * **Age : 나이에 대한 계산 진행**

# %%
# 음수값에 대해서 양수로 변경 / 년에 대한 값을 가지고 몫을 구한다.
train['age'] = - train['DAYS_BIRTH'] // 365
test['age'] = - test['DAYS_BIRTH'] // 365

# %% [markdown]
# * **Employed : 고용년수에 대한 계산**

# %%
# 음수값에 대해서 양수로 변경 / 년에 대한 값을 가지고 몫을 구한다.
train['employed'] = - train['DAYS_EMPLOYED'] // 365
test['employed'] = - test['DAYS_EMPLOYED'] // 365

# %% [markdown]
# * **Card : 카드 발급 월수**

# %%
# 음수값에 대해서 양수로 변경 
train['month_card'] = - train['begin_month']
test['month_card'] = - test['begin_month']

# %%
train.reset_index(drop = True, inplace = True)

# %%
object_col = []
for col in train.columns:
    if train[col].dtype == 'object':
        object_col.append(col)

# %%
from sklearn.preprocessing import LabelEncoder

for i in object_col:
    le = LabelEncoder()
    le=le.fit(train[i])
    train[i]=le.transform(train[i])
for i in object_col:
    le = LabelEncoder()
    le=le.fit(test[i])
    test[i]=le.transform(test[i])

# %%
train = train.drop(['DAYS_BIRTH','DAYS_EMPLOYED','begin_month','parents_num'], axis = 1)
test = test.drop(['DAYS_BIRTH','DAYS_EMPLOYED','begin_month','parents_num'], axis = 1)

# %%
plt.figure(figsize = (20,20))
sns.heatmap(train.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Training

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import log_loss
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
target = 'credit'
x = train.drop(target, axis = 1)
y = train[target]

# %%
# 학습용, 검증용 분리
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x, y,test_size=0.2, stratify = y,random_state=42)

# 평가용
x_test = test

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostClassifier

catboost = CatBoostClassifier(loss_function='MultiClass', eval_metric='MultiClass')
parameters = {'n_estimators':[400,420,440,460,480], 'max_depth':[4,5,6,7,8], 'learning_rate':[0.08,0.09,0.1]}

catboost_best_params = RandomizedSearchCV(catboost, parameters, cv = 5,random_state=42)
catboost_best_params.fit(x_train, y_train)
print(catboost_best_params.best_params_)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 281:	learn: 0.6562123	total: 1.58s	remaining: 1.11s
# 282:	learn: 0.6558526	total: 1.59s	remaining: 1.1s
# 283:	learn: 0.6554807	total: 1.59s	remaining: 1.1s
# 284:	learn: 0.6550783	total: 1.6s	remaining: 1.09s
# 285:	learn: 0.6546084	total: 1.61s	remaining: 1.09s
# 286:	learn: 0.6542729	total: 1.61s	remaining: 1.08s
# 287:	learn: 0.6537463	total: 1.62s	remaining: 1.08s
# 288:	learn: 0.6533730	total: 1.62s	remaining: 1.07s
# 289:	learn: 0.6527314	total: 1.63s	remaining: 1.07s
# 290:	learn: 0.6523238	total: 1.64s	remaining: 1.06s
# 291:	learn: 0.6520835	total: 1.64s	remaining: 1.06s
# 292:	learn: 0.6517672	total: 1.65s	remaining: 1.05s
# 293:	learn: 0.6512947	total: 1.65s	remaining: 1.05s
# 294:	learn: 0.6511321	total: 1.66s	remaining: 1.04s
# 295:	learn: 0.6510178	total: 1.66s	remaining: 1.03s
# 296:	learn: 0.6508448	total: 1.67s	remaining: 1.03s
# 297:	learn: 0.6504952	total: 1.68s	remaining: 1.02s
# ...

# %%
catboost = CatBoostClassifier(n_estimators = 550, max_depth = 8, learning_rate =  0.1,random_state=42)
catboost.fit(x_train, y_train)

pred_catboost = catboost.predict_proba(x_val)
logloss_catboost = log_loss(y_val, pred_catboost, labels=[0, 1, 2])
print(f'log_loss : {logloss_catboost}')
# Out:
# 0:	learn: 1.0428203	total: 10.6ms	remaining: 5.84s
# 1:	learn: 1.0000803	total: 21.4ms	remaining: 5.88s
# 2:	learn: 0.9659054	total: 31.9ms	remaining: 5.82s
# 3:	learn: 0.9378326	total: 41.7ms	remaining: 5.69s
# 4:	learn: 0.9151968	total: 49.4ms	remaining: 5.38s
# 5:	learn: 0.8959933	total: 59.6ms	remaining: 5.41s
# 6:	learn: 0.8804576	total: 69.9ms	remaining: 5.42s
# 7:	learn: 0.8671205	total: 80.6ms	remaining: 5.46s
# 8:	learn: 0.8564128	total: 90.5ms	remaining: 5.44s
# 9:	learn: 0.8472474	total: 97.1ms	remaining: 5.24s
# 10:	learn: 0.8386155	total: 107ms	remaining: 5.25s
# 11:	learn: 0.8319001	total: 117ms	remaining: 5.24s
# 12:	learn: 0.8268727	total: 123ms	remaining: 5.1s
# 13:	learn: 0.8218528	total: 134ms	remaining: 5.12s
# 14:	learn: 0.8176742	total: 144ms	remaining: 5.13s
# 15:	learn: 0.8137133	total: 155ms	remaining: 5.16s
# 16:	learn: 0.8098010	total: 165ms	remaining: 5.17s
# 17:	learn: 0.8066593	total: 175ms	remaining: 5.18s
# ...

# %%
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv')

# %%
y_pred = catboost.predict_proba(x_test)
submit.loc[:,1:]= y_pred
submit
# Out:
# <ipython-input-195-0ac98d395eed>:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   submit.loc[:,1:]= y_pred
#       index         0         1         2
# 0     26457  0.048842  0.022514  0.928645
# 1     26458  0.289609  0.130742  0.579649
# 2     26459  0.077416  0.087856  0.834728
# 3     26460  0.164239  0.212895  0.622866
# 4     26461  0.072670  0.287818  0.639512
# ...     ...       ...       ...       ...
# 9995  36452  0.140060  0.178099  0.681841
# 9996  36453  0.073766  0.297066  0.629168
# 9997  36454  0.013421  0.040058  0.946521
# 9998  36455  0.068176  0.289145  0.642680
# 9999  36456  0.107939  0.223693  0.668367
#
# [10000 rows x 4 columns]

# %%
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv', index=False) # 0.7476

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(colsample_bytree=0.7, learning_rate=0.05, max_depth=8,n_estimators=500, alpha = 1,random_state=42)
xgb.fit(x_train, y_train)

pred_xgb = xgb.predict_proba(x_val)
logloss_xgb = log_loss(y_val, pred_xgb, labels=[0, 1, 2])
print(f'log_loss : {logloss_xgb}')
# Out:
# log_loss : 0.7394563218890466

# %%
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv')

# %%
y_pred = xgb.predict_proba(x_test)
submit.loc[:,1:]= y_pred
submit
# Out:
# <ipython-input-199-877258a8175f>:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   submit.loc[:,1:]= y_pred
#       index         0         1         2
# 0     26457  0.026779  0.064730  0.908491
# 1     26458  0.182045  0.162147  0.655808
# 2     26459  0.052334  0.090659  0.857007
# 3     26460  0.187116  0.159271  0.653613
# 4     26461  0.075904  0.210462  0.713634
# ...     ...       ...       ...       ...
# 9995  36452  0.141121  0.191181  0.667698
# 9996  36453  0.127274  0.258208  0.614518
# 9997  36454  0.017742  0.043397  0.938861
# 9998  36455  0.033490  0.225067  0.741444
# 9999  36456  0.070355  0.274228  0.655417
#
# [10000 rows x 4 columns]

# %%
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv', index=False) # 0.0.7394563218890466

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

RandomForest = RandomForestClassifier(random_state=42)
parameters = {'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3]}

RandomForest_best_params = RandomizedSearchCV(RandomForest, parameters, cv = 5,random_state=42)
RandomForest_best_params.fit(x_train, y_train)
print(RandomForest_best_params.best_params_)
# Out:
# {'n_estimators': 100, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_depth': 30}

# %%
RandomForest = RandomForestClassifier(n_estimators=100, min_samples_split=4, min_samples_leaf=2,max_depth=30,random_state=42) #  0.71957
RandomForest.fit(x_train, y_train)

pred_RandomForest = RandomForest.predict_proba(x_val)
logloss_RandomForest = log_loss(y_val, pred_RandomForest, labels=[0, 1, 2])
print(f'log_loss : {logloss_RandomForest}')
# Out:
# log_loss : 0.7195727754978171

# %%
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv')

# %%
y_pred = RandomForest.predict_proba(x_test)
submit.loc[:,1:]= y_pred
submit
# Out:
# <ipython-input-205-d1a34ff4e300>:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   submit.loc[:,1:]= y_pred
#       index         0         1         2
# 0     26457  0.058395  0.167198  0.774407
# 1     26458  0.231837  0.266837  0.501325
# 2     26459  0.052248  0.076823  0.870929
# 3     26460  0.129934  0.137205  0.732861
# 4     26461  0.103229  0.161092  0.735679
# ...     ...       ...       ...       ...
# 9995  36452  0.104383  0.227379  0.668239
# 9996  36453  0.132961  0.399922  0.467118
# 9997  36454  0.036786  0.071382  0.891832
# 9998  36455  0.090367  0.443431  0.466202
# 9999  36456  0.101000  0.215360  0.683640
#
# [10000 rows x 4 columns]

# %%
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv', index=False) # 0.7195727754978171

# %% [markdown]
# ### Stacking

# %%
estimators = [
    ('catboost', CatBoostClassifier(n_estimators = 550, max_depth = 8, learning_rate =  0.1,random_state=42)),
    ('xgb', XGBClassifier(colsample_bytree=0.7, learning_rate=0.05, max_depth=8,n_estimators=500, alpha = 1,random_state=42)),
    ('RandomForest',RandomForestClassifier(n_estimators=100, min_samples_split=4, min_samples_leaf=2,max_depth=30,random_state=42))
]

# 스태킹 모델 정의
clf = StackingClassifier(
    estimators=estimators,
    cv = 10,
    verbose = 2
)

# 모델 학습
clf.fit(x_train, y_train)

# 모델 예측
pred_clf = clf.predict_proba(x_val)
logloss_clf = log_loss(y_val, pred_clf, labels=[0, 1, 2])
print(f'log_loss : {logloss_clf}')
# Out:
# 0:	learn: 1.0428203	total: 10.7ms	remaining: 5.88s
# 1:	learn: 1.0000803	total: 25ms	remaining: 6.85s
# 2:	learn: 0.9659054	total: 36.9ms	remaining: 6.74s
# 3:	learn: 0.9378326	total: 47.2ms	remaining: 6.44s
# 4:	learn: 0.9151968	total: 55.1ms	remaining: 6s
# 5:	learn: 0.8959933	total: 65.3ms	remaining: 5.92s
# 6:	learn: 0.8804576	total: 75.5ms	remaining: 5.85s
# 7:	learn: 0.8671205	total: 85.6ms	remaining: 5.8s
# 8:	learn: 0.8564128	total: 95.4ms	remaining: 5.74s
# 9:	learn: 0.8472474	total: 102ms	remaining: 5.52s
# 10:	learn: 0.8386155	total: 112ms	remaining: 5.49s
# 11:	learn: 0.8319001	total: 122ms	remaining: 5.47s
# 12:	learn: 0.8268727	total: 129ms	remaining: 5.31s
# 13:	learn: 0.8218528	total: 141ms	remaining: 5.4s
# 14:	learn: 0.8176742	total: 154ms	remaining: 5.48s
# 15:	learn: 0.8137133	total: 164ms	remaining: 5.46s
# 16:	learn: 0.8098010	total: 174ms	remaining: 5.45s
# 17:	learn: 0.8066593	total: 184ms	remaining: 5.44s
# 18:	learn: 0.8037867	total: 194ms	remaining: 5.41s
# ...

# %%
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv')

# %%
y_pred = clf.predict_proba(x_test)
submit.loc[:,1:]= y_pred
submit
# Out:
# <ipython-input-212-010774767cf3>:2: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   submit.loc[:,1:]= y_pred
#       index         0         1         2
# 0     26457  0.060392  0.128540  0.811068
# 1     26458  0.198589  0.238246  0.563165
# 2     26459  0.054253  0.087406  0.858341
# 3     26460  0.113052  0.137622  0.749325
# 4     26461  0.092624  0.156927  0.750450
# ...     ...       ...       ...       ...
# 9995  36452  0.104643  0.194403  0.700954
# 9996  36453  0.133181  0.387707  0.479111
# 9997  36454  0.045542  0.080347  0.874111
# 9998  36455  0.096732  0.424787  0.478481
# 9999  36456  0.097679  0.194647  0.707674
#
# [10000 rows x 4 columns]

# %%
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv', index=False) # 0.719540364269901

# %% [markdown]
# AUTO ML

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 KB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 KB 20.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 KB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 KB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 10.6 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *
from sklearn.metrics import log_loss
import warnings
warnings.filterwarnings('ignore')

# %%
# Pycaret
from pycaret.classification import *
from sklearn.metrics import log_loss

clf = setup(train, target = 'credit', train_size = 0.8)
# Out:
# <style type="text/css">
# #T_14188_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_14188" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14188_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_14188_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14188_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14188_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_14188_row0_col1" class="data row0 col1" >8293</td>
#     </tr>
#     <tr>
#       <th id="T_14188_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14188_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_14188_row1_col1" class="data row1 col1" >credit</td>
#     </tr>
#     <tr>
#       <th id="T_14188_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#logloss 적용 및 predict_proba로 제출하기 위해 metric 추가
add_metric('logloss', 'LogLoss', log_loss, greater_is_better=False, target="pred_proba")
# Out:
# Name                                                           LogLoss
# Display Name                                                   LogLoss
# Score Function                   <function log_loss at 0x7f58c83ffdc0>
# Scorer               make_scorer(log_loss, greater_is_better=False,...
# Target                                                      pred_proba
# Args                                                                {}
# Greater is Better                                                False
# Multiclass                                                        True
# Custom                                                            True
# Name: logloss, dtype: object

# %%
#svm, ridge는 predict_proba 미지원으로 제외
best5 = compare_models(fold = 5, sort = 'logloss', n_select = 3, exclude=['svm','ridge'])
# Out:
# <style type="text/css">
# #T_785c9 th {
#   text-align: left;
# }
# ...

# %%
blended = blend_models(estimator_list = best5, fold = 10, optimize = 'logloss')
pred_holdout = predict_model(blended)
# Out:
# <style type="text/css">
# #T_3075d_row10_col0, #T_3075d_row10_col1, #T_3075d_row10_col2, #T_3075d_row10_col3, #T_3075d_row10_col4, #T_3075d_row10_col5, #T_3075d_row10_col6, #T_3075d_row10_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_3075d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3075d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3075d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3075d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3075d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3075d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3075d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3075d_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_3075d_level0_col7" class="col_heading level0 col7" >LogLoss</th>
# ...

# %%
#lda 와 nb는 losloss가 좋지만 accuracy, auc가 상대적으로 좋지 않아 커스텀모델 생성
custom_model = compare_models(fold = 5, sort = 'logloss', n_select = 6, include=['lightgbm','gbc','rf','ada', 'lda', 'nb'])
# Out:
# <style type="text/css">
# #T_4a3f6 th {
#   text-align: left;
# }
# #T_4a3f6_row0_col0, #T_4a3f6_row0_col2, #T_4a3f6_row0_col5, #T_4a3f6_row0_col6, #T_4a3f6_row0_col7, #T_4a3f6_row0_col8, #T_4a3f6_row1_col0, #T_4a3f6_row1_col1, #T_4a3f6_row1_col2, #T_4a3f6_row1_col3, #T_4a3f6_row1_col4, #T_4a3f6_row1_col5, #T_4a3f6_row1_col6, #T_4a3f6_row1_col7, #T_4a3f6_row1_col8, #T_4a3f6_row2_col0, #T_4a3f6_row2_col1, #T_4a3f6_row2_col2, #T_4a3f6_row2_col3, #T_4a3f6_row2_col4, #T_4a3f6_row2_col5, #T_4a3f6_row2_col6, #T_4a3f6_row2_col7, #T_4a3f6_row2_col8, #T_4a3f6_row3_col0, #T_4a3f6_row3_col1, #T_4a3f6_row3_col2, #T_4a3f6_row3_col3, #T_4a3f6_row3_col4, #T_4a3f6_row3_col5, #T_4a3f6_row3_col6, #T_4a3f6_row3_col7, #T_4a3f6_row3_col8, #T_4a3f6_row4_col0, #T_4a3f6_row4_col1, #T_4a3f6_row4_col3, #T_4a3f6_row4_col4, #T_4a3f6_row4_col8, #T_4a3f6_row5_col0, #T_4a3f6_row5_col1, #T_4a3f6_row5_col2, #T_4a3f6_row5_col3, #T_4a3f6_row5_col4, #T_4a3f6_row5_col5, #T_4a3f6_row5_col6, #T_4a3f6_row5_col7 {
# ...

# %%
blended_custom = blend_models(estimator_list = custom_model, fold = 5, optimize = 'logloss')
pred_holdout_custom = predict_model(blended_custom)
# Out:
# <style type="text/css">
# #T_2b04a_row5_col0, #T_2b04a_row5_col1, #T_2b04a_row5_col2, #T_2b04a_row5_col3, #T_2b04a_row5_col4, #T_2b04a_row5_col5, #T_2b04a_row5_col6, #T_2b04a_row5_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_2b04a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b04a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2b04a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2b04a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2b04a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2b04a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2b04a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2b04a_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_2b04a_level0_col7" class="col_heading level0 col7" >LogLoss</th>
#     </tr>
# ...

# %% [markdown]
# ## Prediction

# %%
#자동으로 상위 5개 선택한 모델
final_model = finalize_model(blended)

#Accurary, AUC, Logloss 셋다 상위 4개인 모델 
final_model_custom = finalize_model(blended_custom)

# %%
#Accurary, AUC, Logloss 셋다 상위 4개인 모델 사용
prep_pipe = get_config('pipeline')
prep_pipe.steps.append(['trained_model', final_model_custom])
prections = prep_pipe.predict_proba(test)
prections
# Out:
# array([[0.13080146, 0.17665941, 0.69253913],
#        [0.20377505, 0.20372464, 0.59250031],
#        [0.13801405, 0.1999269 , 0.66205904],
#        ...,
#        [0.10661527, 0.13433691, 0.75904782],
#        [0.19590135, 0.22762309, 0.57647556],
#        [0.15503916, 0.2887524 , 0.55620844]])

# %%
len(prections)
# Out:
# 10000

# %%
i, j, k = [], [], []
for row in prections:
  i.append(row[0])
  j.append(row[1])
  k.append(row[2])

len(i), len(j), len(k)
# Out:
# (10000, 10000, 10000)

# %%
submit = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv')

# %%
submit['0'] = i
submit['1'] = j
submit['2'] = k
submit.head(10)
# Out:
#    index         0         1         2
# 0  26457  0.130801  0.176659  0.692539
# 1  26458  0.203775  0.203725  0.592500
# 2  26459  0.138014  0.199927  0.662059
# 3  26460  0.147206  0.167591  0.685202
# 4  26461  0.148225  0.244279  0.607496
# 5  26462  0.141112  0.253543  0.605344
# 6  26463  0.311846  0.432012  0.256142
# 7  26464  0.146777  0.226691  0.626532
# 8  26465  0.137230  0.213233  0.649537
# 9  26466  0.124082  0.249440  0.626478

# %%
submit.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv', index=False) # > 0.7851581067
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-36c7230b3b02> in <cell line: 1>()
# ----> 1 submit.to_csv('/content/drive/MyDrive/Colab Notebooks/Project/월간 데이콘 신용카드 사용자 연체 예측 AI 경진대회/sample_submission.csv', index=False) > 0.7851581067
#
# TypeError: '>' not supported between instances of 'NoneType' and 'float'

# %% [markdown]
# ## 결론

# %% [markdown]
# AutoML : 모델자체를 전체적으로 쉽게 돌려줘서 편하지만 성능적 좋지 않게 나왔는데 AutoML의 사용 방법에 대해서 공부를 해야할 것 같다.
#
# 처음으로 스태킹을 이용하여 모델을 돌려봤는데, 이도 여러가지 방법이 있으며,
# 오류도 많이 나고 하는 것 같아서 공부를 해야할 것 같다.
